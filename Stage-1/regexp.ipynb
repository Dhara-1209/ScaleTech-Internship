# %%
import re

# %%
text="i have 15 apples,5 cherry and 2 grape"
result= re.findall(r"\d+",text)
print(result)
# Out:
# ['15', '5', '2']

# %%
text="apple is amazing and ai is awesome"
result=re.findall(r"[Aa][A-Za-z]*",text)
print(result)
# Out:
# ['apple', 'amazing', 'and', 'ai', 'awesome']
